# %%
is5 = [0, 0, 0, 0, 1, 0, 1, 1, 0, 1, 1, 1]
numberof5 = sum(is5)


def calc_precision(pos):
  assert 0 <= pos <= len(is5)
  numvalues = len(is5) - pos
  num5inset = sum(is5[pos:])
  precision = num5inset / numvalues
  return precision


def calc_recall(pos):
  assert 0 <= pos <= len(is5)
  num5inset = sum(is5[pos:])
  recall = num5inset / numberof5
  return recall


values = []
for i in range(len(is5)):
  precision = calc_precision(i)
  recall = calc_recall(i)
  values.append([precision, recall])
  print(f'position {i} precision {precision} recall {recall}')
# Out:
# position 0 precision 0.5 recall 1.0
# position 1 precision 0.5454545454545454 recall 1.0
# position 2 precision 0.6 recall 1.0
# position 3 precision 0.6666666666666666 recall 1.0
# position 4 precision 0.75 recall 1.0
# position 5 precision 0.7142857142857143 recall 0.8333333333333334
# position 6 precision 0.8333333333333334 recall 0.8333333333333334
# position 7 precision 0.8 recall 0.6666666666666666
# position 8 precision 0.75 recall 0.5
# position 9 precision 1.0 recall 0.5
# position 10 precision 1.0 recall 0.3333333333333333
# position 11 precision 1.0 recall 0.16666666666666666

# %%
import matplotlib.pyplot as plt

plt.plot(values)
plt.show()
